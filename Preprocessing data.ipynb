# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\....\\Desktop\\FLV.csv')

# %%
df
# Out:
#        Unnamed: 0    Date   Time                      Source IP address  \
# 0               0  892022  21516                            192.168.1.3
# 1               1  892022  21516                          52.85.221.134
# 2               2  892022  21516  2a02:587:7813:500:f0f7:f781:b084:7d42
# 3               3  892022  21516               2a00:1450:4001:80f::2004
# 4               4  892022  21518                            192.168.1.3
# ...           ...     ...    ...                                    ...
# 14944       14944  892022  22113              2606:4700:4400::ac40:9aa3
# 14945       14945  892022  22113  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
# 14946       14946  892022  22114              2606:4700:4400::ac40:9aa3
# 14947       14947  892022  22114              2606:4700:4400::ac40:9aa3
# 14948       14948  892022  22114  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
#
#                       Destination IP address  Bandwidth     Delay
# ...

# %%
df.set_index(['Source IP address', 'Destination IP address'])
# Out:
#                                                                              Unnamed: 0  \
# Source IP address                     Destination IP address
# 192.168.1.3                           52.85.221.134                                   0
# 52.85.221.134                         192.168.1.3                                     1
# 2a02:587:7813:500:f0f7:f781:b084:7d42 2a00:1450:4001:80f::2004                        2
# 2a00:1450:4001:80f::2004              2a02:587:7813:500:f0f7:f781:b084:7d42           3
# 192.168.1.3                           116.202.225.117                                 4
# ...                                                                                 ...
# 2606:4700:4400::ac40:9aa3             2a02:587:7813:500:b1f1:bd6e:afbb:bcbb       14944
# 2a02:587:7813:500:b1f1:bd6e:afbb:bcbb 2606:4700:4400::ac40:9aa3                   14945
# 2606:4700:4400::ac40:9aa3             2a02:587:7813:500:b1f1:bd6e:afbb:bcbb       14946
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# Date                        int64
# Time                        int64
# Source IP address          object
# Destination IP address     object
# Bandwidth                   int64
# Delay                     float64
# dtype: object

# %%
cols = ['Date','Time']
cols
# Out:
# ['Date', 'Time']

# %%
df[cols] = df[cols].replace('[^\d.]','', regex = True).astype(int)

# %%
df[cols]
# Out:
#          Date   Time
# 0      892022  21516
# 1      892022  21516
# 2      892022  21516
# 3      892022  21516
# 4      892022  21518
# ...       ...    ...
# 14944  892022  22113
# 14945  892022  22113
# 14946  892022  22114
# 14947  892022  22114
# 14948  892022  22114
#
# [14949 rows x 2 columns]

# %%
df
# Out:
#        Unnamed: 0    Date   Time                      Source IP address  \
# 0               0  892022  21516                            192.168.1.3
# 1               1  892022  21516                          52.85.221.134
# 2               2  892022  21516  2a02:587:7813:500:f0f7:f781:b084:7d42
# 3               3  892022  21516               2a00:1450:4001:80f::2004
# 4               4  892022  21518                            192.168.1.3
# ...           ...     ...    ...                                    ...
# 14944       14944  892022  22113              2606:4700:4400::ac40:9aa3
# 14945       14945  892022  22113  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
# 14946       14946  892022  22114              2606:4700:4400::ac40:9aa3
# 14947       14947  892022  22114              2606:4700:4400::ac40:9aa3
# 14948       14948  892022  22114  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
#
#                       Destination IP address  Bandwidth     Delay
# ...

# %%
df.set_index(['Source IP address', 'Destination IP address'])
# Out:
#                                                                              Unnamed: 0  \
# Source IP address                     Destination IP address
# 192.168.1.3                           52.85.221.134                                   0
# 52.85.221.134                         192.168.1.3                                     1
# 2a02:587:7813:500:f0f7:f781:b084:7d42 2a00:1450:4001:80f::2004                        2
# 2a00:1450:4001:80f::2004              2a02:587:7813:500:f0f7:f781:b084:7d42           3
# 192.168.1.3                           116.202.225.117                                 4
# ...                                                                                 ...
# 2606:4700:4400::ac40:9aa3             2a02:587:7813:500:b1f1:bd6e:afbb:bcbb       14944
# 2a02:587:7813:500:b1f1:bd6e:afbb:bcbb 2606:4700:4400::ac40:9aa3                   14945
# 2606:4700:4400::ac40:9aa3             2a02:587:7813:500:b1f1:bd6e:afbb:bcbb       14946
# ...

# %%
df
# Out:
#        Unnamed: 0    Date   Time                      Source IP address  \
# 0               0  892022  21516                            192.168.1.3
# 1               1  892022  21516                          52.85.221.134
# 2               2  892022  21516  2a02:587:7813:500:f0f7:f781:b084:7d42
# 3               3  892022  21516               2a00:1450:4001:80f::2004
# 4               4  892022  21518                            192.168.1.3
# ...           ...     ...    ...                                    ...
# 14944       14944  892022  22113              2606:4700:4400::ac40:9aa3
# 14945       14945  892022  22113  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
# 14946       14946  892022  22114              2606:4700:4400::ac40:9aa3
# 14947       14947  892022  22114              2606:4700:4400::ac40:9aa3
# 14948       14948  892022  22114  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
#
#                       Destination IP address  Bandwidth     Delay
# ...

# %%
import csv

# %%
df.to_csv('C:\\Users\\VasilisFermelis\\Desktop\\FLV.csv')

# %%
df
# Out:
#        Unnamed: 0    Date   Time                      Source IP address  \
# 0               0  892022  21516                            192.168.1.3
# 1               1  892022  21516                          52.85.221.134
# 2               2  892022  21516  2a02:587:7813:500:f0f7:f781:b084:7d42
# 3               3  892022  21516               2a00:1450:4001:80f::2004
# 4               4  892022  21518                            192.168.1.3
# ...           ...     ...    ...                                    ...
# 14944       14944  892022  22113              2606:4700:4400::ac40:9aa3
# 14945       14945  892022  22113  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
# 14946       14946  892022  22114              2606:4700:4400::ac40:9aa3
# 14947       14947  892022  22114              2606:4700:4400::ac40:9aa3
# 14948       14948  892022  22114  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
#
#                       Destination IP address  Bandwidth     Delay
# ...

# %%
df.set_index(['Source IP address', 'Destination IP address'])
# Out:
#                                                                              Unnamed: 0  \
# Source IP address                     Destination IP address
# 192.168.1.3                           52.85.221.134                                   0
# 52.85.221.134                         192.168.1.3                                     1
# 2a02:587:7813:500:f0f7:f781:b084:7d42 2a00:1450:4001:80f::2004                        2
# 2a00:1450:4001:80f::2004              2a02:587:7813:500:f0f7:f781:b084:7d42           3
# 192.168.1.3                           116.202.225.117                                 4
# ...                                                                                 ...
# 2606:4700:4400::ac40:9aa3             2a02:587:7813:500:b1f1:bd6e:afbb:bcbb       14944
# 2a02:587:7813:500:b1f1:bd6e:afbb:bcbb 2606:4700:4400::ac40:9aa3                   14945
# 2606:4700:4400::ac40:9aa3             2a02:587:7813:500:b1f1:bd6e:afbb:bcbb       14946
# ...

# %%
df.values
# Out:
# array([[0, 892022, 21516, ..., '52.85.221.134', 55, 0.0],
#        [1, 892022, 21516, ..., '192.168.1.3', 66, 0.014674],
#        [2, 892022, 21516, ..., '2a00:1450:4001:80f::2004', 75, 0.0],
#        ...,
#        [14946, 892022, 22114, ...,
#         '2a02:587:7813:500:b1f1:bd6e:afbb:bcbb', 1434, 0.004248],
#        [14947, 892022, 22114, ...,
#         '2a02:587:7813:500:b1f1:bd6e:afbb:bcbb', 1434, 0.024639],
#        [14948, 892022, 22114, ..., '2606:4700:4400::ac40:9aa3', 74,
#         0.000123]], dtype=object)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#        Unnamed: 0    Date   Time                      Source IP address  \
# 0               0  892022  21516                            192.168.1.3
# 1               1  892022  21516                          52.85.221.134
# 2               2  892022  21516  2a02:587:7813:500:f0f7:f781:b084:7d42
# 3               3  892022  21516               2a00:1450:4001:80f::2004
# 4               4  892022  21518                            192.168.1.3
# ...           ...     ...    ...                                    ...
# 14944       14944  892022  22113              2606:4700:4400::ac40:9aa3
# 14945       14945  892022  22113  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
# 14946       14946  892022  22114              2606:4700:4400::ac40:9aa3
# 14947       14947  892022  22114              2606:4700:4400::ac40:9aa3
# 14948       14948  892022  22114  2a02:587:7813:500:b1f1:bd6e:afbb:bcbb
#
#                       Destination IP address  Bandwidth     Delay
# ...

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:,1:3]
y = df.iloc[:,6]
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.20)

# %%
y
# Out:
# 0        0.000000
# 1        0.014674
# 2        0.000000
# 3        0.048090
# 4        0.000000
#            ...
# 14944    0.000063
# 14945    0.000017
# 14946    0.004248
# 14947    0.024639
# 14948    0.000123
# Name: Delay, Length: 14949, dtype: float64

# %%
batch_size = 128
epochs = 20
model = Sequential()
model.add(Dense(64, activation= "relu",input_shape=(2,)))
model.add(Dropout(0.2))
model.add(Dense(64, activation= "relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation= "linear"))
model.compile(loss= "mse", optimizer= "Adam")
hist=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose =1, validation_split=(0.1))
# Out:
# Epoch 1/20
# 85/85 [==============================] - 1s 3ms/step - loss: 1010031424.0000 - val_loss: 1759596.6250
# Epoch 2/20
# 85/85 [==============================] - 0s 2ms/step - loss: 98856160.0000 - val_loss: 2484955.0000
# Epoch 3/20
# 85/85 [==============================] - 0s 2ms/step - loss: 28297828.0000 - val_loss: 148221.9062
# Epoch 4/20
# 85/85 [==============================] - 0s 2ms/step - loss: 12216585.0000 - val_loss: 52829.7969
# Epoch 5/20
# 85/85 [==============================] - 0s 3ms/step - loss: 6584663.0000 - val_loss: 18124.8750
# Epoch 6/20
# 85/85 [==============================] - 0s 3ms/step - loss: 3894870.5000 - val_loss: 8577.7588
# Epoch 7/20
# 85/85 [==============================] - 0s 3ms/step - loss: 2887191.7500 - val_loss: 5357.2397
# Epoch 8/20
# 85/85 [==============================] - 0s 2ms/step - loss: 2412018.5000 - val_loss: 1674.9221
# Epoch 9/20
# ...

# %%
new_sample = [[892022,21516]]
raw_output = model.predict(new_sample)
# Out:
# 1/1 [==============================] - 0s 56ms/step

# %%
raw_output
# Out:
# array([[2.4990423]], dtype=float32)

# %%
df.isnull().sum()
# Out:
# Date                      0
# Time                      0
# Source IP address         0
# Destination IP address    0
# Bandwidth                 0
# Delay                     0
# dtype: int64
